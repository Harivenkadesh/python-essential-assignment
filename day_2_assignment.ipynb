# %% [markdown]
# <a href="https://colab.research.google.com/github/Harivenkadesh/python-essential-assignment/blob/main/day_2_assignment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# String functions
a= " Harivenkadesh "
b=" venkadesh "

print(len(a))
print(len(b))

print(a[1:5])
print(b[5:7])

print(a.upper())
print(b.upper())

print(a.lower())
print(b.lower())

print(a.strip())
print(b.strip())

print(a.split( ))
print(b.split())

a = a.upper();
b = b.lower();

print(a.isupper())
print(a.islower())
print(b.isupper())
print(b.islower())

# List functions

c= ['a', 1, 'c', 3.0, 'b', 2 ]

print(len(a))

print(c[2:])

c.append('d')
print(c)

c.insert(7, 4.0)
print(c)

c.remove(1)
print(c)

c.pop(2);
print(c)

c.pop(3)
print(c)

c.pop()
print(c)

c.sort();
print(c)

c.sort(reverse= True)
print(c)

#Dictionary functions

dic = {
    "FirstName"   : "Hari",
    "MiddleName"  : "venkadesh",
    "LastName"    : "Gopalakrishnan",
    "Age"         : 20,
    "Course"      : "Python Essentials",
    "Day"         : 2
}

print(dic)

print(len(dic))

print(dic["Course"])

print(dic.get("Course"))

print(dic.keys())

print(dic.values())

dic["Assignment"] = 1

print(dic)

print(dic.values())

dic.update({"MiddleName": "Sriram"})
print(dic)
# Out:
# 15
# 11
# Hari
# ad
#  HARIVENKADESH
#  VENKADESH
#  harivenkadesh
#  venkadesh
# Harivenkadesh
# venkadesh
# ['Harivenkadesh']
# ['venkadesh']
# True
# False
# False
# True
# 15
# ['c', 3.0, 'b', 2]
# ['a', 1, 'c', 3.0, 'b', 2, 'd']
# ['a', 1, 'c', 3.0, 'b', 2, 'd', 4.0]
# ['a', 'c', 3.0, 'b', 2, 'd', 4.0]
# ['a', 'c', 'b', 2, 'd', 4.0]
# ['a', 'c', 'b', 'd', 4.0]
# ['a', 'c', 'b', 'd']
# ['a', 'b', 'c', 'd']
# ['d', 'c', 'b', 'a']
# {'FirstName': 'Hari', 'MiddleName': 'venkadesh', 'LastName': 'Gopalakrishnan', 'Age': 20, 'Course': 'Python Essentials', 'Day': 2}
# 6
# Python Essentials
# Python Essentials
# dict_keys(['FirstName', 'MiddleName', 'LastName', 'Age', 'Course', 'Day'])
# dict_values(['Hari', 'venkadesh', 'Gopalakrishnan', 20, 'Python Essentials', 2])
# {'FirstName': 'Hari', 'MiddleName': 'venkadesh', 'LastName': 'Gopalakrishnan', 'Age': 20, 'Course': 'Python Essentials', 'Day': 2, 'Assignment': 1}
# ...
